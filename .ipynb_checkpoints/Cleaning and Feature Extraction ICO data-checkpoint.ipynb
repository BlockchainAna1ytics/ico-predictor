# %%
import json
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
from datetime import datetime

# %%
f = open('ico_bench_data_cleaned.json', 'r')
ico_data = json.loads(f.read())
df = pd.DataFrame.from_dict(ico_data)
f.close()
"""
df = df.replace('^\s+$', np.nan)
df = df.replace('', np.nan)
df = df.dropna()
df.distributed = df.distributed.map(lambda item : float(item[:-1].strip().replace(',', '.')) / 100, 'ignore')
"""
# Out:
# "\ndf = df.replace('^\\s+$', np.nan)\ndf = df.replace('', np.nan)\ndf = df.dropna()\ndf.distributed = df.distributed.map(lambda item : float(item[:-1].strip().replace(',', '.')) / 100, 'ignore')\n"

# %%
df
# Out:
#                        accepting  \
# 0                          [ETH]
# 1                          [ETH]
# 2                          [ETH]
# 3                          [NEO]
# 4      [ETH, BTC, LTC, ETC, BCH]
# 5          [BTC, ETH, BCH, Fiat]
# 6                          [ETH]
# 7                     [ETH, BNB]
# 8                     [ETH, BTC]
# 9                     [ETH, BTC]
# 10     [BTC, ETH, CHF, EUR, USD]
# 11                         [ETH]
# 12                         [ETH]
# 13                    [Ethereum]
# 14                         [ETH]
# 15             [ETH, BTC, Waves]
# 16                    [BTC, ETH]
# 17                         [ETH]
# 18    [ETH, BTC, LTC, BCH, Dash]
# 19                         [ETH]
# 20               [ETH, BTC, LTC]
# 21                         [ETH]
# 22                         [ETH]
# 23              [ETH, BTC, Fiat]
# 24                    [ETH, BTC]
# 25               [ETH, BTC, LTC]
# 26                    [ETH, BTC]
# 27               [ETH, BTC, LTC]
# 28              [ETH, BTC, KICK]
# 29                         [ETH]
# ...                          ...
# 2055                       [ETH]
# 2056                       [ETH]
# 2057                       [BTC]
# 2058                       [ETH]
# 2059                  [ETH, BTC]
# 2060                         NaN
# 2061                       [BTC]
# 2062                         NaN
# 2063                         NaN
# 2064                      [Fiat]
# 2065                       [BTC]
# 2066                         NaN
# 2067            [ETH, BTC, Fiat]
# 2068                       [BTC]
# 2069                       [ETH]
# 2070                         NaN
# 2071                       [ETH]
# 2072                  [BTC, ETH]
# 2073                       [ETH]
# 2074                         NaN
# 2075                 [BTC, MAID]
# 2076                         NaN
# 2077                       [BTC]
# 2078                         NaN
# 2079                         NaN
# 2080                         NaN
# 2081                         NaN
# 2082                       [ETH]
# 2083                       [ETH]
# 2084                         NaN
#
#                                              categories distributed  \
# 0                                            [Big Data]         40%
# 1     [Big Data, Artificial Intelligence, Business s...         55%
# 2                            [Cryptocurrency, Platform]         50%
# 3     [Platform, Internet, Cryptocurrency, Communica...         65%
# 4                  [Legal, Business services, Platform]         70%
# 5     [Platform, Cryptocurrency, Communication, Bank...         80%
# 6     [Cryptocurrency, Investment, Legal, Platform, ...         50%
# 7                             [Platform, Entertainment]         40%
# 8                      [Entertainment, Platform, Media]         75%
# 9      [Cryptocurrency, Entertainment, Media, Platform]         50%
# 10                                         [Investment]        4.3%
# 11       [Big Data, Business services, Media, Software]         31%
# 12    [Platform, Health, Communication, Business ser...         70%
# 13    [Artificial Intelligence, Business services, C...         23%
# 14    [Tourism, Platform, Health, Communication, Big...       56.5%
# 15               [Cryptocurrency, Investment, Software]         48%
# 16    [Platform, Infrastructure, Cryptocurrency, Sof...         85%
# 17    [Big Data, Business services, Cryptocurrency, ...       52.5%
# 18    [Business services, Communication, Cryptocurre...       37.5%
# 19    [Internet, Cryptocurrency, Artificial Intellig...         33%
# 20    [Smart Contract, Platform, Entertainment, Cryp...         70%
# 21    [Business services, Cryptocurrency, Infrastruc...         66%
# 22                            [Banking, Cryptocurrency]         30%
# 23    [Entertainment, Communication, Business servic...         60%
# 24                                           [Software]         64%
# 25    [Entertainment, Casino & Gambling, Investment,...         75%
# 26    [Internet, Infrastructure, Cryptocurrency, Bus...         40%
# 27    [Business services, Cryptocurrency, Legal, Pla...      45,11%
# 28                                   [Platform, Retail]       73.8%
# 29    [Artificial Intelligence, Cryptocurrency, Inve...         85%
# ...                                                 ...         ...
# 2055   [Cryptocurrency, Platform, Software, Investment]         NaN
# 2056                             [Entertainment, Media]         85%
# 2057                                         [Platform]         NaN
# 2058                                   [Cryptocurrency]         80%
# 2059                        [Casino & Gambling, Sports]         NaN
# 2060                                   [Cryptocurrency]         NaN
# 2061                                    [Entertainment]         NaN
# 2062                                [Casino & Gambling]         NaN
# 2063                                         [Platform]         NaN
# 2064                                         [Platform]         NaN
# 2065                                         [Platform]         NaN
# 2066                                         [Platform]         50%
# 2067                                   [Cryptocurrency]         NaN
# 2068                                         [Platform]         NaN
# 2069                                   [Cryptocurrency]         NaN
# 2070                                       [Investment]         NaN
# 2071                                       [Investment]         NaN
# 2072                                           [Energy]         NaN
# 2073                                    [Entertainment]         NaN
# 2074                                   [Cryptocurrency]         NaN
# 2075                                         [Platform]         NaN
# 2076                         [Platform, Cryptocurrency]         NaN
# 2077  [Platform, Cryptocurrency, Business services, ...         NaN
# 2078                [Cryptocurrency, Business services]         NaN
# 2079      [Platform, Cryptocurrency, Business services]         NaN
# 2080                                [Casino & Gambling]         NaN
# 2081                    [Entertainment, Cryptocurrency]         NaN
# 2082                                   [Cryptocurrency]         NaN
# 2083                      [Casino & Gambling, Software]         NaN
# 2084                                   [Cryptocurrency]         NaN
#
#            end_date                        hard_cap min_investment  \
# 0     26th Jul 2018                      20,000,000            NaN
# 1     29th Jun 2018                          20,000            0.5
# 2     21st Jul 2018                  10,000,000,000              5
# 3     21st Apr 2018                      10,000,000              1
# 4     30th Apr 2018                      $6,000,000            NaN
# 5     18th Jul 2018                      88,000,000            500
# 6      2nd Jul 2018                     150.000.000            0.1
# 7     16th May 2018                      18,000,000            0.2
# 8     24th Jul 2018                          25,000            NaN
# 9     11th Jul 2018                      25,000,000            100
# 10    27th Jun 2018                      30,000,000            NaN
# 11     4th Jul 2018                          15,000            0.2
# 12    31st May 2018                      28 000 000            NaN
# 13     8th Jul 2018                       7,000,000            NaN
# 14    23rd Jul 2018                      10 000 000            0.1
# 15     8th Jun 2018                      15,000,000            0.1
# 16    13th Jun 2018                       3,000,000            NaN
# 17     4th Jul 2018                      38,000,000            NaN
# 18    31st May 2018                          45,000            0.1
# 19    28th Oct 2017                             NaN            NaN
# 20    30th Apr 2018                          10,300            0.1
# 21     3rd Jul 2018                           3,800            0.5
# 22    15th Jul 2018                     600.000.000              1
# 23    14th Mar 2018  3,000,000  (-), 12,000,000  ()   0.05 , 0.005
# 24    31st May 2018                      15,000,000            NaN
# 25     1st Jun 2018                     750,000,000            0.1
# 26     1st Jul 2018                      20,000,000         50,000
# 27    25th Jul 2018                      22,000,000            0.5
# 28    20th Jul 2018                      24,000,000            200
# 29    18th Jul 2018                          26,500            0.1
# ...             ...                             ...            ...
# 2055   1st Feb 2018                           14000            NaN
# 2056   1st Dec 2017                             NaN            NaN
# 2057   6th Jul 2017                             500            NaN
# 2058  31st Dec 2017                             NaN            NaN
# 2059  27th Aug 2017                             NaN            NaN
# 2060   9th Mar 2018                      10 000 000            NaN
# 2061   1st Nov 2017                             NaN            NaN
# 2062  12th Mar 2018                             NaN            NaN
# 2063   1st Jan 2018                             NaN            NaN
# 2064  14th Jun 2018                             NaN             50
# 2065  30th Jun 2017                             NaN            NaN
# 2066  30th Aug 2017                             NaN            NaN
# 2067  15th Dec 2017                     200,000,000          10000
# 2068  24th May 2017                             NaN            NaN
# 2069   6th Jul 2017                             NaN            NaN
# 2070  17th Jan 2018                             NaN            NaN
# 2071   1st Jul 2018                             NaN            NaN
# 2072  31st May 2018                             NaN            NaN
# 2073  19th Aug 2017                             NaN            0.1
# 2074   7th May 2017                             NaN            NaN
# 2075   3rd May 2017                             NaN            NaN
# 2076  31st Dec 2017                             NaN            NaN
# 2077  24th Dec 2017                             NaN            NaN
# 2078  21st May 2017                            1500            NaN
# 2079  15th Sep 2016                             NaN            NaN
# 2080  29th Oct 2017                             NaN            NaN
# 2081  20th May 2017                             NaN            NaN
# 2082  11th Jul 2017                             NaN            NaN
# 2083  26th Jun 2017                             NaN            NaN
# 2084  22nd Sep 2017                             NaN            NaN
#
#                         name        price                    raised  \
# 0                   Quadrant   1  = 0.05                        NaN
# 1                    Airbloc      0.0410                 $2,300,000
# 2                   AMO Coin      0.0022                        NaN
# 3               Concierge.io      = 0.35                 $2,640,110
# 4                Jury.Online      0.5100                 $3,927,409
# 5                   Nauticus      0.0741                $16,916,000
# 6                   Telluria      0.0840
# 7          The Abyss (DAICO)      0.1100                $15,362,418
# 8                     TV-TWO      0.0350                 $8,700,000
# 9                   Verasity      0.0106                 $4,000,000
# 10                  Alethena      0.0100                   $583,000
# 11               BitScreener      0.0830                 $6,910,800
# 12                 DIW Token      0.0690                   $913,551
# 13                   Elysian   1  = 0.12                 $7,000,000
# 14                    Etheal      0.7592                   $820,000
# 15             MetaMorph.pro      0.0800
# 16                    Paymon  1  = 0.015                 $1,092,514
# 17                 ShareRing      0.0200                 $1,550,980
# 18                   Sharpay      0.0170                 $5,973,900
# 19                Swarm Fund      1.0000                 $5,500,000
# 20                  Truegame  1  = 9,250                 $3,426,445
# 21                Whalesburg      0.3120
# 22                  Zantepay      0.2900                   $700,000
# 23                    AdHive      0.1369                $12,000,000
# 24                BitRewards      0.0198                 $6,583,400
# 25           Cryptonia Poker      0.0800                 $7,823,333
# 26                    Dbrain      2.0000                 $2,500,000
# 27                  EtherInc      0.1000
# 28                  FLOGmall      0.2300                $23,212,696
# 29                      FTEC      0.0154                   $995,000
# ...                      ...          ...                       ...
# 2055                  altOWL      0.0000
# 2056                    Anna   5000  = 1
# 2057                 Dochain      0.0340     $1,306,290500.00000000
# 2058          Ethereum Metal      1.0000
# 2059                Imperium      0.1159
# 2060        Island Coin Gold          NaN
# 2061             MakeItViral     -1.0000           $9,0001.15000000
# 2062                  MyOddz      0.2800
# 2063                   Orada          NaN
# 2064             Retail Coin      0.1508                        NaN
# 2065               Sphre AIR      0.1890   $5,272,7322,052.71689646
# 2066            TomahawkCoin      0.0500
# 2067                 V-Coins          NaN
# 2068                   YOYOW      0.0160   $4,364,7602,000.00000000
# 2069               300 Token     79.7640         $16,72463.00000000
# 2070               Bitfinite      0.7500
# 2071  Blockchain Traded Fund      0.8980
# 2072                 Credits      0.0100                 $1,000,000
# 2073      Hungry Panda Games      2.9302
# 2074                    MCAP      4.0000                $44,287,318
# 2075         Project Decorum          NaN                  $400,000
# 2076                 Binance      0.1000
# 2077             Emiratecoin      0.0100
# 2078                     APX      0.6000   $2,749,1851,500.00000000
# 2079                Blockpay      0.1240     $538,3601,000.00000000
# 2080              CryptoChip          NaN
# 2081        The Legends Room      1.0000
# 2082  Useless Ethereum Token      0.0200        $80,520310.44500000
# 2083                   iDice          NaN                $2,500,000
# 2084               RegalCoin      0.9700
#
#      rating_benchy rating_product rating_team rating_vision     soft_cap  \
# 0              4.4            5.0         4.6           4.5    3,000,000
# 1              4.5            3.0         3.4           2.9        7,000
# 2              4.8            4.4         4.5           4.1          NaN
# 3              4.9            3.7         4.4           3.9    2,000,000
# 4              4.1            4.2         4.1           4.7   $3,000,000
# 5              4.9            4.6         4.8           4.4    8,000,000
# 6              4.9            2.6         2.6           2.7          NaN
# 7              4.8            3.8         4.0           4.1    6,000,000
# 8              4.9            3.9         4.3           4.2        2,500
# 9              4.9            3.9         4.5           4.2    4,000,000
# 10             4.9            2.9         3.3           3.1    3,000,000
# 11             4.5            4.0         4.3           4.1        1,000
# 12             4.6            4.1         4.6           4.2          NaN
# 13             4.5            4.2         4.7           4.5    3,000,000
# 14             4.3            4.0         4.4           4.4    4 800 000
# 15             4.8            2.5         3.5           1.5    1,000,000
# 16             4.3            4.2         4.4           4.4      500,000
# 17             4.9            3.6         4.5           3.9          NaN
# 18             4.9            4.6         4.6           4.7      3000000
# 19             4.5            3.9         4.5           3.9          NaN
# 20             4.8            4.8         4.8           4.7        2,300
# 21             4.8            3.9         3.8           3.7        1,000
# 22             4.3            3.8         4.1           3.8   10.000.000
# 23             4.6            4.0         4.4           4.3    2,000,000
# 24             4.6            4.5         4.6           4.3    3,000,000
# 25             4.3            3.7         3.8           3.8          NaN
# 26             4.5            2.8         3.3           2.6    5,000,000
# 27             4.9            4.0         4.3           4.6    1,000,000
# 28             4.6            3.5         3.8           3.8    8,000,000
# 29             4.6            4.7         4.7           4.8        2,000
# ...            ...            ...         ...           ...          ...
# 2055           1.0              -           -             -          NaN
# 2056           1.0              -           -             -          NaN
# 2057           1.0            1.3         1.6           1.3          NaN
# 2058           1.0            1.0         1.0           1.0          NaN
# 2059           1.0            1.0         1.0           1.0          NaN
# 2060           1.0            1.0         1.0           1.5          NaN
# 2061           1.0            1.0         1.0           1.0           40
# 2062           1.0            1.5         1.7           1.7          NaN
# 2063           1.0            1.0         1.0           1.0          NaN
# 2064           1.5              -           -             -          NaN
# 2065           1.0            1.3         1.3           1.3          NaN
# 2066           1.0            1.7         1.6           1.7    5,000,000
# 2067           1.0            1.0         1.0           1.0   10,000,000
# 2068           1.0            1.0         1.0           1.0          NaN
# 2069           0.9            1.0         1.0           1.0          NaN
# 2070           0.9            1.1         1.1           1.1          NaN
# 2071           0.9            1.0         1.0           1.0          NaN
# 2072           0.9            1.0         1.1           1.1  100,000,000
# 2073           0.9            1.4         1.6           1.6          500
# 2074           0.9            4.0         1.0           4.0          NaN
# 2075           0.9            2.1         2.0           2.1          NaN
# 2076           0.7            4.5         4.7           4.3          NaN
# 2077           0.7            1.0         1.2           1.0          NaN
# 2078           0.6            1.0         1.0           1.2          NaN
# 2079           0.6            3.2         3.2           3.2          NaN
# 2080           0.6            1.0         1.0           1.1          NaN
# 2081           0.6            1.5         1.5           1.9          NaN
# 2082           0.6            1.0         1.0           1.0          NaN
# 2083           0.5            1.0         1.2           1.0          NaN
# 2084           0.6            1.3         1.1           1.3          NaN
#
#          start_date
# 0     26th Jul 2018
# 1     19th Jun 2018
# 2     14th Jul 2018
# 3     31st Mar 2018
# 4     12th Feb 2018
# 5     19th May 2018
# 6      7th May 2018
# 7     18th Apr 2018
# 8     24th May 2018
# 9     21st May 2018
# 10     6th Jun 2018
# 11    19th May 2018
# 12     3rd May 2018
# 13    18th Jun 2018
# 14    25th Jun 2018
# 15    28th Jun 2018
# 16    10th May 2018
# 17     3rd Jun 2018
# 18     1st Mar 2018
# 19    21st Oct 2017
# 20    16th Apr 2018
# 21     3rd Jun 2018
# 22    15th Apr 2018
# 23    28th Feb 2018
# 24    12th Apr 2018
# 25     1st May 2018
# 26    15th Apr 2018
# 27    15th Jul 2018
# 28    26th Apr 2018
# 29    20th Jun 2018
# ...             ...
# 2055   7th Dec 2017
# 2056  10th Oct 2017
# 2057   6th Jul 2017
# 2058   2nd Dec 2017
# 2059  20th Aug 2017
# 2060  19th Jan 2018
# 2061  18th Jul 2017
# 2062  12th Feb 2018
# 2063   1st Dec 2017
# 2064  15th Apr 2018
# 2065   1st Jun 2017
# 2066  30th Jul 2017
# 2067  15th Nov 2017
# 2068  21st May 2017
# 2069  30th Jun 2017
# 2070  18th Dec 2017
# 2071   1st Dec 2017
# 2072   2nd Apr 2018
# 2073  19th Jul 2017
# 2074  27th Apr 2017
# 2075   8th Apr 2017
# 2076  31st Dec 2017
# 2077  13th Nov 2017
# 2078   1st May 2017
# 2079  23rd Aug 2016
# 2080  29th Sep 2017
# 2081  18th Apr 2017
# 2082   4th Jul 2017
# 2083  12th Jun 2017
# 2084  22nd Aug 2017
#
# [2085 rows x 15 columns]

# %%
mlb = MultiLabelBinarizer()
df = df.join(pd.DataFrame(mlb.fit_transform(df.pop('accepting')), columns=mlb.classes_, index=df.index))
df = df.join(pd.DataFrame(mlb.fit_transform(df.pop('categories')), columns=mlb.classes_, index=df.index))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d419438e290d> in <module>()
# ----> 1 mlb = MultiLabelBinarizer()
#       2 df = df.join(pd.DataFrame(mlb.fit_transform(df.pop('accepting')), columns=mlb.classes_, index=df.index))
#       3 df = df.join(pd.DataFrame(mlb.fit_transform(df.pop('categories')), columns=mlb.classes_, index=df.index))
#       4 df.loc[df.raised == "Unknown"]
#
# NameError: name 'MultiLabelBinarizer' is not defined

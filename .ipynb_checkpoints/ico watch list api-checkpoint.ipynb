# %%
import requests
import pandas as pd

# %%
json_response = requests.get('https://api.icowatchlist.com/public/v1/finished').json()
data = json_response['ico']['finished']
with open('icoWatchListData.json', 'w') as f:
    f.write(json.dumps(data))

# %%
documents = [item['description'] for item in data]
print(len(documents))
documents
# Out:
# 628
# ['Augur is a decentralized prediction market',
#  'It is a cryptocurrency and decentralized application platform',
#  'A Decentralized Autonomous Organization focused on goldtracking assets',
#  'Waves helps to make the launching and coordination of projects on blockchain very easy',
#  'Antshares is a China based smart contract blockchain project',
#  'Stratis was developed to help organisations develop their own private blockchains',
#  'Tao Network posits itself as a digital asset management system meant to be used by stakeholders in the music industry',
#  'Incent is a blockchain based loyalty program for traders especially retailers',
#  'This is a retail platform that allows multicryptocurrency payment',
#  'FirstBlood is a eSports matches and betting project',
#  'The Iconomi platform helps users with simple methods to enter the growing distributed economy',
#  'Global market space based on blockchain',
#  'Synereo is a decentralized and distributed social network',
#  'This is a film and television studio and also a distribution portal based on blockchain technology',
#  'Video Game in Real Time',
#  'Decent is a content distribution project',
#  'The Golem platform enables personal computers to perform functions traditionally reserved for servers',
#  'The Ark project aims to make cryptocurrency adoption mainstream as quickly as possible',
#  'Betting Game based on the Ethereum Blockchain',
#  'Komodo is a decentralized ICO platform',
#  'Golos is open source technology bringing the power of voice media to blockchain',
#  'CreativeCoin for the registration and distribution of creative works and rights',
#  'A decentralized platform for the creation management and interlinking of DAOs',
#  'Tokes is a digital currency project for the legalization of the cannabis industry',
#  'Time based currencies on multiple blockchains',
#  'A smart contract platform for PoS transactions',
#  'Edgeless solves Casino transparency problems through the use of the Ethereum blockchain',
#  'IeXec is a fully decentralized cloud based computing system based on Blockchain',
#  'Encrypto Telecom offers solutions for secure communication over the blockchain',
#  'it is an Ethereumbased prediction market that works using crowdsourcing methods',
#  'MobileGoGameCredit is a proprietary payment gateway that allows gamers to use the tokens to buy ingame content',
#  'Decentralized Banking based on blockchain',
#  'The future of knowledge sharing that lets you earn rewards for what you know',
#  'TaaS is a tokenized closedend fund specifically for blockchainbased assets',
#  'BlockPool is a B2B blockchain solution for many industries Fintech Media  more ',
#  'Token Market has been setup as the platform for the future financial era',
#  'EcoBit is taking charge in the fight to make the planet a safe and healthier place for us all to live in',
#  'BOScoin is a selfevolving cryptocurrency platform',
#  'Blockchain Capital is a venture capital firm investing in blockchain enterprises',
#  'ZrCoin is a blockchain project for investing in the production of an indemand industrial material',
#  'Aeternity is a new smart contract blockchain that interfaces with IoT FinTech  more',
#  'It is an easytouse secure cryptocurrency with an organization that has a futureoriented mindset',
#  'Peerplays is a provably fair blockchainbased gaming platform',
#  'The Aragon platform lets a whole organization operate with the infrastracture of the blockchain technology',
#  'Monaco is creating a cryptocurrency card with extra affordable exchange rates ',
#  'Storj is a platform allows users to store data in a secure and decentralized manner',
#  'Crypviser is an encrypted network for business and social on the Blockchain technology',
#  'The Quantum Resistant Ledger QRL is new technology which is resistant to hacking by quantum computers',
#  'CryptoPing is a real time altcoins trading intelligence chatbot as a service',
#  'Adel is a selfsustaining cryptocurrency system',
#  'Veritaseum is a smart contractsbased peertopeer wallet interface',
#  'Mysterium is an open sourced network that enables anyone to rent out their unused network traffic',
#  'Exscudos main goal is to integrate cryptocurrencies into the traditional financial',
#  'Patientory is a distributed electronic medical record storage computing platform on the blockchain ',
#  'Basic Attention Token is bringing blockchain technology to digital advertising',
#  'Wagerr is a decentralized sportsbook that changes the way the world bets on sports',
#  'NVO is building a crossplatform modular decentralized exchange',
#  'SphreAir is a smart contract based platform for the secure management and monetisation of digital identities',
#  'Dcorp is an autonomous organization system based on a smartcontract blockchain solution',
#  'Giga Watt facilitys distinctive infrastructure consists of numerous independent mining units ',
#  'A platform that levels the playing field for all musicians',
#  'The Bancor protocol allows anyone to easily create completely liquid smart tokens',
#  'FundYourselfNow is a platform that will allow project creators raise funds for projects without the need of technical cryptocurrency knowledge',
#  'MinexCoin is a global payments system based on a low volatility cryptocurrency which is a part of Minex ecosystem',
#  'Compcoin is an investment system that uses AI  blockchain',
#  'SONM is a decentralized worldwide fog computer for any general purpose computing from site hosting to scientific calculations',
#  'Status is a browser app and messenger gateway to a decentralized world',
#  'The first Cryptocurrencyfunded blockchain INDY TV series',
#  'Beth is a closedend fund focused on applying deep learning research combined with financial expertise',
#  'Each coin in the OneGram blockchain is backed by 1 gram of 24k gold',
#  'Secure access to identity verification via the blockchain',
#  'Internet of Coins is a new peertopeer financial network on the blockchain',
#  'Populous is a smart contract invoice system on the blockchain',
#  'Primalbase is an offices workspace sharing platform managed on the blockchain',
#  'Digital advertising powered by Ethereum',
#  'Omise GO is a blockchain wallet solution built on the Ethereum platform for payments rewards points and much more',
#  'MyBit is a decentralized asset management project built to add an ownership layer to the internet',
#  'Bitquence is making to cryptocurrency world accessible to more people and market',
#  'Santiment will analyze crypto market trends and help cryptotraders manage risk ',
#  'A VC Ecosystem based on blockchain technology',
#  'The Metal project aims to transform how digital money operates',
#  'InsureX is a marketplace for insurance based on blockchain technology',
#  'Dent builds the global exchange for mobile data on the blockchain ',
#  'Smart contract platform that can evolve and in theory will never need any hard forks',
#  'TenX develops a debit card that is connected to your blockchain assets',
#  'This is a network that creates decentralized communities and market places',
#  'Stox is a prediction market platform for traders built on the Ethereum blockchain',
#  'Starta Capital VC Fund created the startup investing accelerator on the Waves platform',
#  'Physical assets financing platform on the Ethereum blockchain',
#  'Crowd vouching platform  allows people to earn money vouching for other people who need a loan',
#  'Hive provides new financial liquidity to small businesses by leveraging blockchain technology ',
#  'Decentralized platform for freelancers based on Etheruem ',
#  '0x is a protocol for a decentralized exchange of Ethereums ERC20 tokens and assets',
#  'CoinDash is an asset management platform for crypto investors that enables users to view other portfolios in realtime',
#  'This is a a blockchain based virtual reality platform',
#  'Cyber security on the blockchain The Token provides proof and assurance of security on the hardware level',
#  'Cryptocurrency  secure messaging platform built on the Stratis blockchain',
#  'Crypto platform built on Ethereum Classic with a price controlled currency',
#  'iMPERIUM is a NOFEE sports betting platform built on the Ethereum network',
#  'Trading cryptocurrencies with artificial intelligence technology',
#  'The First ICO for Adult Entertainment',
#  'Bowhead is a medical instrument powered by the blockchain technology',
#  'Financial platform for organizing investment assets on the blockchain',
#  'Welcome to a proficient installment answer for dealers that empowers comprehensively trustful trade Decentralized Enabled by the Ethereum blockchain',
#  'Benja is a decentralized merchandise ad network ',
#  'Tron is a decentralized content entertainment protocol based on blockchain technology',
#  'Arena is a cryptocurrency sports predication and betting system',
#  'Snapup disrupts the way you buy premium products',
#  'A decentralized storage network',
#  'This is a decentralized content market place based on blockchain',
#  'Ahoolee is the worlds first search engine for products',
#  'Merging Blockchain Technology with Lottery  eGaming',
#  'A revolutionary global standard for a more fair secure and transparent ticketing industry',
#  'Daseron is the worlds decentralized and secure information system for selling and sharing of content',
#  'Cryptocurrency gambling  Online casino technology on the blockchain ',
#  'First token which allows blockchain community to vote for the best projects to be brought to life through their own ICOs',
#  'KICKICO is the first already working platform for crowdfunding and crowdinvesting in cryptocurrency',
#  'Decentralized insurance platform built on Ethereum ',
#  'KyberNetwork is a system which allows the exchange and conversion of digital assets ',
#  'Cryptocurrency cloud mining tools that reduces mining fees',
#  'DETECTOR DTCT is a bot that monitors cryptocurrency and betting markets',
#  'Kik one of the most popular massaging apps in the world is creating a crypto token for its ecosystem',
#  'Augmented reality combat game with social features and a decentralized crypto token',
#  'jNET1 is a platform that enables B2B and B2C jewelrybased transactions',
#  'Litra is here to create uncontested new market space that make the competition irrelevant by decentralize Healthcare',
#  'AxionV is an agile AI crypto fund that uses proprietary algorithms and complex trading methods to consistently outperform the market',
#  'MPX is partnered with the Moneypot network to provide the fuel for a versatile webwallet gaming platform and bitcoinaltcoin exchange',
#  'Technology of authenticity verification of video content',
#  'Decentralized data marketplace',
#  'A decentralized sex marketplace with a goal to enable all human beings on earth to find their perfect sexual partner anonymously ',
#  'Power Ledger is a blockchainbased peertopeer energy trading platform enabling consumers and businesses to share excess solar power with their neighbours',
#  'Decentralized Blockchain auctions in realtime DRT tokens',
#  'Decentralized higher education  student community blockchain project',
#  'Solving ticketing issues for the event industry',
#  'The project is establishing a platform to help investors hedge their bets',
#  'Bringing blockchain technology to the world of legal cannabis industry',
#  'A tool that offers all you need for your professional growth and also a way to share knowledge and get paid or not',
#  'Ethbet is a decentralized peertopeer and provablyfair Ethereumbased dicing game without a house edge',
#  'Fast easy and not only a Multicurrency Wallet its a Hybrid Exchange too Its Eidoo',
#  'Blockchain based digital goods and services',
#  'Mobile internet access using advertising and microloans',
#  'The LINK Network provides smart contracts with data bank payments and access to APIs',
#  'Decentralized platform for crypto assets management in various life circumstances',
#  'The most private accountless exchange with 50 profit sharing',
#  'COBINHOOD is the worlds first ZERO Trading Fees cryptocurrency exchange with the vision to maximize traders profits',
#  'A friendly sex dating service based on a blockchain Do you believe in sex',
#  'Bookira is created to make the online booking process easier while reducing the risk and costs for users',
#  'The foundation of the Virtual Goods Economy',
#  'Modular marketplace supernetwork initially powering the Cannabis industry',
#  'KeYtoken aims to establish the nextgeneration smartbank and a worldwide exchange network on blockchain platform',
#  'An asset management platform for investing in ICOs',
#  'Social public opinion poll network on the blockchain',
#  'A decentralized social market place',
#  'Cooperative Ownership Platform for Real Assets',
#  'Onlinetranslation platform based on blockchain',
#  'Tokenlab offers Token and ICO services to clients towards their fund raising campaigns',
#  'The Grant Hero Foundation is a decentralized nonprofit organization that fosters direct personal giving Grant Hero enables donors to create and award personal grants direct to recipients offering complete autonomy and transparency',
#  'Central entry point into a decentralized space',
#  'Aeron  the new standard of aviation safety powered by blockchain',
#  'AIintegrated Augmented Reality applications and cloud service',
#  'Payment processing system for acceptance of digital currencies',
#  'Atlant aims to be the Worlds Real Estate Blockchain Platform',
#  'Green Blockchain  Mining with monthly dividends',
#  'Dentacoin The Blockchain Solution for the Global Dental Industry',
#  'The first and only erc20 Ethereum casino',
#  'A global peertopeer credit network based on cosigned smart contracts',
#  'Blockchain platform for ticket systems and event organisers',
#  'The future of online payments',
#  'A Platform for issuing tokens and launch crowdfunding projects',
#  'Qvolta will let people convert cryptocurrencies into the fiat currencies',
#  'Taxi rides aggregator service on the wave blockchain platform',
#  'Trading bot advisor with smart algorithms to gather useful trading information globally',
#  'Blockstack has been designed as the new internet for decentralized apps',
#  'Genesis Vision is the platform for the private trust management market built on blockchain technology and smart contracts',
#  'Lending company with modern analytical platform',
#  'First Internet Bandwidth Marketplace powered by P2P VPN Network on Blockchain',
#  'COPICO is the project powering the XCPO masternode Coin',
#  'MicroMoney is an Open Source Credit  Big Data Bureau that connects new customers to all existing financial services',
#  'First Decentralized Career Oriented  Skills Training Platform',
#  'Modern online poker room based on blockchain technology',
#  'Attracting people to work in the clothing manufacturing industry',
#  'Decentralized Data and AI Marketplace',
#  'Decentralized financial instruments on ERC20 tokens',
#  'Blockbid is an ultrasecure exchange with the goal of facilitating the highest volume of trades for the most cryptocurrencies with a single login',
#  'Escrow Platform on The Ethereum Blockchain',
#  'The child safety system that will be used to protect children on the roads and streets',
#  'A multifunctional multithreaded trading platform in the cloud',
#  'First Ecomining in the World Recycling platform on the blockchain',
#  'Blockchain powered wallet and debit card for variety of cryptocurrencies Bonpay makes transactions as simple as possible',
#  'A decentralized platform that enables anyone to operate a fully functioning virtual asset marketplace',
#  'Creating the StorMarket  a decentralized microtask marketplace platform ',
#  'Decentralized Cloud Gaming Platform',
#  'The Value for Human Capital Enabled by Smart Contracts',
#  'Vezt lets music fans share ownership with artists in their favorite songs',
#  'Multicryptocurrency payment platform for businesses consumers  community',
#  'Your Crypto Payment Platform',
#  'Blockchain revolution for the publishing economy',
#  'Dmarket  the first decentralized marketplace where you can trade all your ingame items globally',
#  'Decentralized Platform for Digital Identification and Social Scoring Engine',
#  'Privacy Focused Blockchain Timestamping Office',
#  'A Blockchain based decentralized video streaming platform ',
#  'Digital Currency powered by Ethreum represented by Diamonds',
#  'The autonomous algorithmic trading blockchain fund',
#  'AML BitCoin is the first AML KYC compliant coin for legitimate financial use on a global scale',
#  'Modern Banking Solutions For The Digital World Tomorrow',
#  'Oracle Platform and Prediction Market',
#  'Blockchain Protocol for Digital Insurance built for InternetofThings',
#  'The largest healthcare blockchain Medibloc will help champion the worlds shift to private information decentralization',
#  'Smart Cryptocurrency for gaming and trading',
#  'The First Cryptocurrency fund for real estate development and investment',
#  'Automated Intelligent Trading App Help Traders and Investors Get Good Returns On Their Investments',
#  'ProsenseLive is the worlds first decentralized peertopeer livestreaming platform for the distribution of virtual reality content',
#  'Neufund is a communityowned fundraising platform',
#  'Blockchain PlatformMarketplace integrating business apps  solutions to collaborative environments',
#  'Investy is a platform for decentralized investments',
#  'We are reinventing the global equity market',
#  'AI and Blockchain Powered Chatbot Ecosystem',
#  'Foreground is an affiliate marketing solution for the traditional internet and the rapidly growing decentralized web',
#  'The first immersion cooling system for PC',
#  'Connectius  a blockchain SaaS solution for ecommerce',
#  'Aims to unlock the power of blockchain technology to revolutionize traditional insurance industry',
#  'Tokens bought with Ethereum and distributed to participants backed by immoveable property',
#  'Online Sports Lottery Platform with Provably Fair Results 15 Profit Share for Token Holders',
#  'Indahash is tokenizing the influencer industry',
#  'Borderless SME business financing',
#  'kevin is an innovative online banking service that allows to easily link and manage different crypto accounts and bank accounts',
#  'Hdac is the worlds 1st IoT Contract  Payment Platform based on Blockchain',
#  'Ethereum High is a robust and featherlight cryptocurrency designed to hedge the risk of your portfolio',
#  'The easiest way to get started in the financial market',
#  'Sirin Labs is building an ultra secured  open sourced communication device for the blockchain era',
#  'Access Management solution replacing passwords with the distributed authentication',
#  'Decentralized ecosystem directly connecting grocery manufacturers and consumers',
#  'The biggest energy revolution ever',
#  'Real working platform for a 2 trillion dollar peer to peer market',
#  'DesAnti Scam helps to protect blockchain investors from financial losses',
#  'ETHLend a blockchain startup that introduces decentralized lending it aims to enable decentralized lending globally by allowing crypto borrowing',
#  'A ProofofAsset Protocol that brings together BankasaService and Blockchain technology to evolve capital markets Tokenization of realworld and financial assets',
#  'Spectiv is a signal token protocol',
#  'NAU directly links buyers and sellers n a retail market',
#  'A decentralized Android app store combined with an ICO developer platform crypto exchange that accepts payment in cryptocurrency ',
#  'LHCoin is a token with monthly income from operational activities',
#  'LIVESHOW is creating a webcam platform of a new generation which is based on blockchain technology',
#  'STYRAS Connects everyone anywhere and everywhere',
#  'First investment blockchain option in the oil and gas sector',
#  'Freedom Streaming offers a full live streaming platform that allows you to stream from anywhere in the world uncensored safe and anonymously',
#  'Bringing Smart Contacts to Smart Parents',
#  'Cryptonetix will be the foremost blockchain asset management analytics funding and educational platform for the rapidly growing cryptocurrency markets',
#  'Fantasy Market is an innovative marketplace where users control the performers through the use of our token',
#  'Decentralized Lending Network of Masternodes',
#  'tradeio is an innovative new blockchain trading platform that will disrupt the financial ecosystem and democratize the markets',
#  'We help Banks buy Bitcoin',
#  'The Blockchain Traded Fund is a closed ended fund that invests in the best Ethereum',
#  'Cash meets digital currencies',
#  'Progressive financial infrastructure for professional footballers',
#  'The New Era of Swiss Private Banking with Smart Contracts',
#  'Lendoit is the only True Decentralized P2P Lending Platform using Blockchain Technology',
#  'Digital mobile cryptobank',
#  'ENVION makes mining green  mobile',
#  'GATCOIN transforms traditional discount coupons loyalty points and shopping vouchers into liquid tradable digital tokens',
#  'Revolutionary copytrading platform combined with the most complete infrastructure for investors and cryptocurrency traders',
#  'AppCoins is the first cryptocurrency for app stores serving 200 million active users',
#  'The tZERO platform integrates cryptographically secure distributed ledgers with existing market processes to reduce settlement time and costs',
#  'Solareum brings solar energy on Blockchain',
#  'New DAG tech based cryptocurrency decentralized social travel network and payment system',
#  'Blockchain with totally decentralized P2P economic infrastructure which authenticates digital rights and turns digital information into assets ',
#  'The First Real Estate Coupon Ethereum Token for Purchasing Properties',
#  'The worlds first blockchainpowered online education platform with token scholarships  tech talent acquisition',
#  'LiveEdu is Youtube for Online Education the nextgeneration Lyndacom',
#  'The Decentralized Real Estate Platform',
#  'Jibrel provides traditional financial assets such as currencies bonds and equities as standard ERC20 tokens on the Ethereum Blockchain',
#  'Polimath is the interface between financial securities and the blockchain',
#  'Storiqa  a marketplace with a wide range of functions for effective sales in the world of a new digital economy',
#  'FLIP Cryptotoken for gamers from gaming experts',
#  'A 3D marketplace that allows users to create and share virtual reality VR experiences ViMarket promises to bring about a muchneeded breakthrough in the global ecommerce ecosystem',
#  'The worlds first decentralized blockchain driven marketplace ecosystem',
#  'Kind Ads is an advertising platform that serves userfriendly ads without taking any middleman fees',
#  'CrowdWiz  Bringing the future of investment into your hands',
#  'Decentralizing ShortTerm Housing Rentals Blockchain Powered Platform With 0 Commissions Network Effects',
#  'Disrupting transport and logistics on the Blockchain',
#  'Shping is an innovative shoppermarketing ecosystem that enables participating brands and organisations the opportunity to reward shoppers who use the Shping App with a new cryptocurrency called Shping Coin',
#  'Global wireless internet service providerpowered by blockchain',
#  'Global Decentralized Blockchain Platform For Automotive Industry',
#  'AidCoin is the token for charitable giving built on Ethereum Blockchain',
#  'EnergiToken rewards energy saving behaviour',
#  'WePower is launching blockchain and smart contracts powered green energy trading platform',
#  'A Peertopeer lending service that works with Cryptocurrency and Fiat',
#  'Sharpe Capital is a blockchain based investment fund that invests in cryptocurrency assets based on predictions from token holders Token holders who make accurate predictions earn Ether',
#  'Escape games booking service powered by Blockchain Technology',
#  'ArcBlock is a platform and an ecosystem for building and deploying decentralized blockchain applications',
#  'Blockchain based inclusive cryptofinance platform',
#  'Scorum is the first sports social media powered by blockchain',
#  'The glocal decentralized justintime factory 40',
#  'Major EU energy company launches energy trading ecosystem and the first power retail franchise',
#  'Invest your spare change into diversified portfolios of cryptocurrencies and crypto assets',
#  'Buy  sell crypto for cash Spend it at physical stores',
#  'Empowering BlockchainBased Digital Marketing The Most Powerful Digital Marketing Solutions on Blockchain',
#  'CryptoIBet is the next generation platform for online gaming experience',
#  'Futureoriented platorm for exchanging real objects for cryptocurrency',
#  'FuzeX offers an all in one payment solution that provides a smarter way to pay Paying with cryptocurrency debit credit and reward cards is easier',
#  'Matrix has been built as a distributed network of artificial intelligence and blockchain',
#  'Decentralised digital marketing platform',
#  'An opensource decentralized dark pool for trustless crosschain atomic trading of Ether ERC20 tokens and Bitcoin pairs',
#  'A blueprint for disintermediated financial services',
#  'A decentralized payment system powered by everyday consumption',
#  'The first community app dedicated to events in real time that rewards users with its own cryptocurrency usable anywhere in the world',
#  'A modern solution for reliable global money transactions',
#  'The Blockchain Investment Platform',
#  'Decentralised banking platform Access to a bank account for P2P financial services for anyone in the world',
#  'BioFactoryCoin BFC the first factory in the world producing healthy milk production with availability for cryptocurrency payments',
#  'Protecting you from cryptocurrency fraud',
#  'Local World Forwarders is the first decentralized logistics platform based on the blockchain',
#  'ODYSSEYs mission is to build the nextgeneration decentralized sharing economy  Peer to Peer Ecosystem',
#  'A Global Market place for the safe and secure trading of secondary metals',
#  'HOQU is the worlds first Decentralized Affiliate Platform',
#  'The first decentralized financialmarketplace as a DAO using Blockchain Technology',
#  'Blockchain powered Streaming Video on Demand Connecting content creators directly with consumers ',
#  'MARKSPACE is worlds first opensource platform for creation of 3D VR and ARcompatible websites units and objects and for their fast integration into a single ecosystem The platform is Blockchainbased and supported by miners',
#  'AI Platform for investment and personal finance',
#  'Decentralized Home Rental Platform',
#  'Stockchain Global brings a global blockchainbased platform to the market for issuance trading and management of financial instruments',
#  'The first gaming online casino based on Ethereum',
#  'A Blockchain platform that aims to help SMEs build their IoT products  solution faster by connecting them to skilled IoT developers',
#  'Saving the Future of Chocolate using the Blockchain',
#  'Platform for keeping personal diplomas certificates and licenses in blockchain',
#  'A new era of cloud computing services powered by blockchain technology',
#  'Blocklancer is a Decentralized Autonomous Job Market DAJ on the Ethereum platform',
#  'Token based businesstobusiness B2B marketing sales and trade platform',
#  'We make crypto easy',
#  'Join the Augmented Reality Revolution with Lucyd',
#  'A Blockchain Empowered Digital Advertising Terminal',
#  'APEX passes value and data ownership back to consumers increases marketing effectiveness data quality and customer loyalty',
#  'Lympo is building an app a fitness wallet which will help people to reach their healthy lifestyle goals and earn tokens in return',
#  'An IoTbased contactless identification system that empowers retailers to identify and better serve their customers',
#  'CREDITS Cryptocurrency and Blockchain platform for the financial industry with more than 1 mln txsec and 001 sec for a transaction',
#  'Vionex is a revolutionary blockchainbased smart home system',
#  'MinerDog coin pays you monthly dividends in Ether from profits of our crypto mining operations',
#  'The first 100 algorithmic crypto asset manager',
#  'The worlds first AllinOne solution for cryptocurrencies',
#  'The first ever created decentralized platform for convenient cryptocurrency trading',
#  'KYCLEGAL is the identity verification platform on a blockchain',
#  'Corusblock is the next generation of cryptocurrency Lending staking mining in best performance This is Corusblock',
#  'Affordable clean water for everyone under the sun',
#  'Blockchain technology for secure storage and transfer of electronic health records It provides the infrastructure for digital health applications',
#  'Blockchainbased decentralized secure messenger and fastestgrowing social network',
#  'ELECTRIFY is the first retail electricity marketplace in SoutheastAsia addressing the need for transparency and security',
#  'Helbiz is a decentralized transportation marketplace that makes renting a vehicle convenient affordable and rewarding',
#  'Daneel purpose is to bring data intelligence into the crypto jungle',
#  'IPSX is the first truly decentralized IP Sharing Exchange that will create a distributed network layer',
#  'JET8 is a decentralized mobile engagement network connecting influencers audiences and brands through the value of social currency',
#  'A decentralised payment network and stable coin',
#  'The First Blockchain Escrow for Financial Markets',
#  'The Alibaba of Wealth Management PHI means Platform for Hybrid Investments but also Hybrid Platform for Investing',
#  'UltraFast Blockchain technology from Telegram messenger',
#  'DoSoftwareTogether  Dogezer is a software development platform that allows team members to become product investors by investing their time and labor',
#  'Ocean Protocol is an ecosystem for sharing data and associated services',
#  'Decentralized Crowdlending  Maximize returns from your money',
#  'The first inheritable digital asset',
#  'First fully scalable decentralized freelance task market',
#  'The future of portfolio investment',
#  'Sp8de is a blockchainbased platform capable of supplying unbiased public randomness for developing and running distributed gaming apps',
#  'A Decentralized Lead Sharing Network The blockchain technology feature of the LeadCoin platform enables realtime lead sharing',
#  'dApps launchpad and global marketplace without middlemen',
#  'Refereum cuts out the marketing middleman by directly rewarding influencers and gamers to promote and play video games',
#  'DECENTRALIZED DATA EXCHANGE FOR THE TRAVEL INDUSTRY where travelers and businesses profit from sharing their info',
#  'Ethereum Blockchain Betting  Gambling with Profit Share',
#  'Tracking produce on the Ethereum blockchain',
#  'The first decentralized streaming platform for gamers and eSports fans',
#  'VISO is a payment system that combines cryptocurrencies and traditional bank cards and terminals into one ecosystem',
#  'Bringing Gaming into the 21st Century',
#  'Decentralized hardware manufacturing Syncfab helps to make use of Smart Manufacturing Blockchain',
#  'Cryptocurrency wallet and worldwide debit cards',
#  'Medical analysis and research artificial intelligence application',
#  'Capdax is one of the first exchanges that introduces premium customer service social trading and infrastructure stability',
#  'VALID is a fully integrated personal data management platform',
#  'The ultimate eSports betting cryptocurrency',
#  'NOAHCOIN is Creating A Borderless World Through Blockchain to help empower people financially',
#  'An institutionalgrade cryptocurrency exchange allowing everyone to trade commodities and money market instruments for Bitcoin',
#  'Opporty is a decentralized service marketplace and selfregulated knowledgesharing community platform',
#  'The first AIpowered platform for influencer marketing',
#  'Viewly is a decentralized video platform powered by blockchain and peertopeer video sharing technologies',
#  'Decentralized ARVR ecosystem for 3D content exchange',
#  'BlockchainPowered global solution that builds decentralized online marketplaces faster and easier than current models',
#  'First coffee trading ecosystem entirely supporting smallscale farmers traders roasters and retailers',
#  'FundFantasy is an online social platform featuring peertopeer provablyfair simulated investing contests',
#  'Vestopia is a decentralized peertopeer investment ecosystem connecting the mass population to wealth and investment opportunities in an unprecedented model',
#  'EXENIUM is a fullyfunctional cryptocurrency exchange implemented as a chatbot for messengers',
#  'The Social Platform for Visual Content Monetization',
#  'KnowledgeSharing social network platform powered by Ethereum Blockchain',
#  'Booleancoin Powers Boolean A News Accuracy Platform Aiming To Combat Fake News In The Media',
#  'A blockchain broker which will bring no spread no swap and no commission to traders worldwide',
#  'Solutions for the decentralization of startups financing the franchise market and the real estate market',
#  'Joy Token is a new development platform specifically for the creation and marketing of online casino games',
#  'Worlds first multiasset wallet and personal financial passport',
#  'Technology which covers the treatment process of raw domestic waste and green waste from agriculture',
#  'Trusted Token and Confidence System',
#  'ENSBID focuses on offering the best identity storage and domain name service to the decentralized world of Ethereum',
#  'Be Part of the Next Generation Wiki',
#  'Entrepreneurs and Startups can Pitch Investors Live on the Platform',
#  'Eliminate Traditional Applications with Data That Thinks',
#  'A Decentralized Open Innovation platform that connects entrepreneurs and supporters',
#  'First decentralized Blockchain construction platform',
#  'Integrated production of organic beef from farm to table',
#  'Forty Seven Bank is financial technology startup aimed at building a bridge between cryptocurrency world and the world of traditional monetary finance',
#  'Handelion is a revolutionary blockchain ecosystem for cofunded wholesale trade',
#  'ABCHAIN ADVERTISING NETWORK  Blockchain and AI for enhanced campaigns',
#  'A global distribution and ecommerce marketplace for refurbished consumer electronics',
#  'Blockchain infrastructure aimed to host train and use artificial intelligence AI in healthcare',
#  'ClearCoin is a technology company that powers the realtime buying and selling of media on decentralized applications and the broader digital environment',
#  'The anonymous and safe payment method of the adult industry',
#  'Draganddrop smart contracts',
#  'First and only global decentralized ecosystem directly connecting coffee producers and consumers using the blockchain technology',
#  'True Reply is the future of voicebased datacollection across IoT devices and telephones',
#  'PAYSURA is providing the International PayReward Coin IPC in order to create a worldwide uniform reward system that applies the advantages of the Blockchain Technology',
#  'Solving copyright issues forever',
#  'Decentralized online Gaming EcoSystem for Gamers',
#  'Bitcoin Exchange with 6 in 1 consisting of LendingStakingSignalReferralBorrowingTrading',
#  'Ethereum Based Collectible Trading Card Game driven by the gaming platform token elementeum ELET',
#  'Enabling crypto spending in everyday life',
#  'Cryptocurrency market place for goods and services',
#  'Blockchainbased Decentralized Advertising Marketplace',
#  'Moving target defense  ultimate security on blockchain',
#  'RepuXs blockchainbacked platform enables Small and Medium Enterprises SMEs to securely sell their data',
#  'The blockchain financial system guaranteed by Hash Power enable easiest access to crypto portfolio and trade settlement for EVERYONE',
#  'Renteum is going to be the first of its kind to tie its token to realestate in Scandinavia and England',
#  'Bills is a technology that allows placing advertisements to an outdoor billboard located in any part of the world within a couple of minutes',
#  'Rewarding customers for their loyalty engagement and feedback using cryptocurrencies',
#  'The number one blockchain fuel for the transport industry',
#  'Data science marketplace to help you discover create and monetize cryptocurrency trading',
#  'The real global gaming network',
#  'Creating a universal digital payment engine to power a smart secure and efficient healthcare ecosystem accessible anywhere at anytime',
#  'Travel for a Blockchain Era  Pay for goods and services whiles enjoying great discounts',
#  'An open and decentralized platform for video broadcast and remote consultations markets',
#  'The latest way to profit from Real Estate',
#  'An international ecommerce site created for users  from all over the world who sell and buy various products and services with tokens',
#  'Decentralized Market Intelligence Network for Publishers and Stakeholders',
#  'ViolaAI is the Worlds First AIdriven Marketplace for Dating and Relationships with real business backing of 13 years',
#  'iOlite allows anyone to write smart contract using any language natural or programming',
#  'Branded debit cards and secure payment infrastructure for all companies and ICOs that issue cryptocurrencies',
#  'RentAway is an online global platform the unique rental marketplace that will facilitate rental transactions between private individuals peertopeer and businesses for a wide range of goods equipment and real estate',
#  'Implementing AI at the heart of the Blockchain',
#  'An independent video distribution platform with native eco approach to advertising based on machine learning',
#  'Midex makes cryptocurrency use accessible to business traders and everyday users Midex is a financial ecosystem which encompasses the needs of each economic agent through a fully licensed and encrypted exchange',
#  'Intelligent Technology for Wireless Energy For Private and Commercial Use',
#  'Dapp for gaming tournament and lending platform',
#  'Ecommerce Solution for the Creative and Entertainment Industry',
#  'Decentralized trading platform for sale of innovative indiegadgets run by manufacturers',
#  'App that allows bank customers to settle transactions instantly',
#  'Giftcoin is a groundbreaking new system designed to revolutionise charitable giving',
#  'Benebit is a global decentralized ecosystem that enables interaction without borders between brands companies and consumers and is built on Blockchain technology',
#  'With over 1 million locationverifying beacons already in the world XYO is blockchain39s first cryptolocation oracle network',
#  'A decentralized matchmaking platform revolutionizing how people meet',
#  'PeertoPeer exotic car trading platform',
#  'Rexpax encourages lending and sharing among neighbors',
#  'RiskHedging Platform for cryptocurrency investors DeHedge helps the investor guard against market volatility',
#  'Bringing professional trading tools to everyone',
#  'Smart Contract Powered Retirement Plans AUCTUS Helps People Plan Ahead of Retirement',
#  'Decentralized  community driven platform that integrates Blockchain iGaming eSports and Fantasy Sports',
#  'The Smart Startup Token project is Making Blockchain Accessible to Startups and Small Businesses',
#  'Fully collateralised borrowing and lending of crypto assets',
#  'The Blockchain Appstore Designed for Gamers',
#  'Global Cryptocurrency Exchange and interactive Social platform',
#  'Advanced Cryptocurrency Exchange and Informational Marketplace',
#  'Pangea Arbitration Token PAT powers the Pangea Jurisdiction',
#  'The Smartest Decentralized Peertopeer lending platform',
#  'Gluons platform establishes an interconnected network of vehicles and owners for diagnostics',
#  'First postquantum crypto currency with multiple blockchain',
#  'eSport  Online Gaming platform  Decentralized games Sports Betting and Casino using blockchain smart contracts  Provably Fair',
#  'ConnectJob ultimately connects jobs to people and people to jobs using the power of blockchain technology',
#  'A platform with optional private  smart contracts and feeless transactions',
#  'Revenue sharing on the blockchain A regular stream of quarterly profit payments',
#  'Applied technology of AI and blockchain to work together via the smart FIC application',
#  'Internet Of Things Artificial Intelligence  Blockchain empowering energy consumers',
#  'Exclusive Trading Service for Forex and Cryptocurrencies for maximized earnings',
#  'Platform for encrypted data sharing',
#  'A seamless ecommerce continuum Eliminating middle men reducing global carbon emissions and more',
#  'MediChain will bring better health to patients with the help of blockchain technology',
#  'ThinkCoin is a Multi Asset Trading which leverages blockhain technology to ensure that investors get optimal returns',
#  'Innovations Global Opportunites and a new World with Blockchain Technology',
#  'Platform that utilizes blockchain technology to provide a onestop solution for the purchase sale and crowdsale of real estate globally',
#  'IPStock implements visual digital content registry on blockchain and license management through smartcontracts',
#  'Elementh is a blockchain designed for the ecommerce market',
#  'DNN is a Political News Platform Fighting Fake News and Combating Censorship',
#  'Altcoin Mining Operation Using Smart Contracts  Based On the Ethereum Blockchain',
#  'Paymon is a blockchain platform that connect all market participants through new scalable blockchain  Hive',
#  'Virtual Reality platform for streamed live events and productions making use of Blockchain Technology',
#  'Deploying Blockchain tehnology to Customers Loyalty Rewards',
#  'Intimate is a cryptocurrency facilitating payments and trust for the adult industry',
#  'AIdriven and blockchainbased cognitive commerce platform',
#  'PATRON is a one stop shop for social media influencers worldwide whiles using blockchain technology and cryptocurrency',
#  'Innovating Optimizing  Reimagining the Fan Experience with the infusion of Blockchain Technology',
#  'Peertopeer content delivery network where anyone can monetize the unused capacity of their computers and smartphones',
#  'The Global BlockchainGenomics Ecosystem Powering the Next Era of Precision Medicine',
#  'BitGuild will disrupt the gaming industry by creating a platform for games that live on the blockchain',
#  'Lunes is a platform which provides a set of decentralized solutions through blockchain',
#  'Every bit of your future secured on the Blockchain Ambit helps everyone earn from cryptocurrency mining',
#  'Blockchain powered augmented reality ecosystem merging real and virtual worlds worldwide creating augmented reality layer  the Digital Land',
#  'Earn and Pay Interest on Your Crypto Assets Fixed Income Infrastructure on Blockchain',
#  'The blockchainpowered ecommerce platform with 0 commissions on every purchase',
#  'invest Cryptocurrencies in Real World Assets in a process to encourage mainstream adoption',
#  'Revolutionaising Global Trade and Transport through Decentralisation with a focus on the shipping industry',
#  'Transparency and Autonomy in Investment powered through the use of the unique Blockchain Technology',
#  'SMARTRealty is revolutionizing the real estate industry',
#  'Mobile gaming combined with Augmented Reality',
#  'Synthestech is a scientific research center engaged in technology development for synthesis of precious metals and valuable isotopes',
#  'Decentralized free wifi network powered by blockchain',
#  'The Future of Gold and Diamond mining',
#  'DreamTeam  Infrastructure platform and payment gateway for esports and gaming',
#  'Mira is a software suite for buying storing and sending cryptocurrencies in an easy and convenient way',
#  'Blockchain solution for Businesses of all size shapes and form for improved processes and systems efficiency',
#  'Green Energy Green Mining Cryptocurrency mining in an ecofriendly environment',
#  'The unified framework for blockchain based business integration to maximize efficiency and profits',
#  'LikeCoin aims to reinvent the Like by realigning creativity and reward',
#  'Crowd Machine is powering the next generation of decentralized blockchain applications',
#  'Rentything  Worlds 1st Decentralized P2P Renting Platform Airbnb for Everything RentGetPaid',
#  'Mass Vehicle Ledger Ecosystem MVL Ecosystem pronounced as embuh l Ecosystem is a new blockchainbased ecosystem created for use in the vehicle industry',
#  'Artificial intelligence platform for blockchain built on the basis of natural language processing technologies',
#  'SMOKE is the cryptocurrency of the SmokeNetwork The first cannabis community to combine blockchain technology with soc',
#  'BunnyToken is a payment solution for the 103 billion adult industry',
#  'The blockchain and cryptotoken based marketing automation platform',
#  'Coinadvisor is a trading platform for arbitrage bot and a multi accounts management tool',
#  'Send and receive money like a text or email messages through encryption',
#  'Blockchain Services and Product Ecosystem Development bringing many benefits to users and stakeholders',
#  'The fastest successful match',
#  'The Future of Advertising Adblur helps to make marketing and advertising very easy and it reduces costs',
#  'Trading and Finance all on one platform It is a onestopshop for cryptocurrency and cryptoasset trading',
#  'Blockchain driven healthcare network built on decentralising access to medical data',
#  'GoChain is a scalable Ethereum based smart contract blockchain that is fast secure and green',
#  'DIW is a secure blockchainbased digital platform which safeguards and secures your digital life',
#  'Birdchain  blockchain based A2P2P Application to person to person app',
#  'Educational investment on Blockchain Enable everybody to share their knowledge and skills through our future online learning system',
#  'A decentralized easy to use peer2peer cryptocurrency insurance platform',
#  'Tokenizing and digitalizing Real Estate Investments through the application of Blockchain Technology',
#  'All Coins One Platform Trade over 10000 direct coin cross rates in one place',
#  'Revolutionizing travel with a sharing economy powered by Blockchain for efficiency transparency and security',
#  'A customized Payment Solution for the Education Personal and Professional Development Industries',
#  'The first professional sports league built on the blockchain and controlled by the fans',
#  'Ecosystem capable of meeting the million people needs in an affordable interesting creative and wellpaid online job',
#  'Transcodium aims to provide the first peertopeer blockchain based and decentralized media transcoding editing and distribution platform with high quality and reliable computational power at a very affordable price',
#  'Gamblica is an international gambling platform based on innovative digital solutions and blockchain technology',
#  'The primary goal of Bitminutes ICO is to provide access to key financial services for over two billion unbanked worldwide',
#  'Infrastructure for building inclusive financial systems for all and sundry using blockchain',
#  'A powerful infrastructure for decentralized apps ',
#  'A platform that unites novice and experienced investors',
#  'The Future of Real Estate with decentralized Portal  All in One Software Solution for the Agents',
#  'Blockchain meets culture connect visitors institutions and artists',
#  'StasyQ brings crypto revolution to the adult industry',
#  'Secure and Decentralized File Sharing Infrastructure using blockchain technology',
#  'MoneyToken provides cryptobacked loans stablecoin MTC and a decentralized exchange service',
#  'Oil Backed Coin CoinOil will be supported by assets in physical oil  oil futures',
#  'White Rabbit allows you to reward the films and series you stream on whatever peertopeer platform you choose to stream them from',
#  '4th Generation Blockchain with a Multidimensional Structure POS',
#  'The GIF in GIFcoin stands for Gambling Investment Fund Gamers get to make winning in a provably fair gambling system',
#  'A blockchain based car raffle platform with profit dividend paid out to token holders',
#  'First blockchain platform for modeling industry which operates as an intermediary between service providers and customers',
#  'Airchain is the next revolution in Freight Industry for unrivaled transparency and efficiency',
#  'Blockchain streaming platform to disrupt the global TV',
#  'Decentralized Cryptocurrency Exchange with Fiat onboarding',
#  'Decentralized Property Transaction  Investment Platform',
#  'A PERSONALIZED MEDICINE OF THE FUTURE A modern system of biorhythm monitoring with the most sophisticated tools for analysis and realtime diagnostics',
#  'Decentralized Blockchain service platform for funds It is a Dapp of a public chain designed for the financial industry',
#  'Your Personal Bar on the Cloud',
#  'Investments in swiss real estate on blockchain basis to help streamline the industry make it more efficient and profitable',
#  'DACC is the worlds first contentbased blockchain that features identity and access management IAM at the infrastructure level',
#  'Ensuring the accessibility of efficient healthcare globally using blockchain',
#  'Deedcoin is the blockchain of the real estate industry reducing commissions by over 80 with licensed agents anywhere',
#  'Making crowdfunding easy and accessible to anyone anywhere and at anytime',
#  'Decentralized Social Urban Network for Online Marketing Focused on Local Business',
#  'Australias First  Largest Crowd Funded Mining Operation',
#  'The Savage Token project is a  democratized tokenized reputationbased stock media platform that rewards millions of digital content creators without the need for any central middlemen',
#  'ICST is a platform used to identity store and protect creative content using blockchain technology',
#  'PRETHER Cryptocurrency backed by Precious Metals to give intrinsic value to investors',
#  'The most secure and anonymous messenger encrypted with Blockchain ADAMANT will bring a new user experience to messaging',
#  'Healthcare Delivered WELL With Blockchain technology WELL is set to revolutionize the healthcare industry',
#  'Parcel Delivery with Precision and Speed Using Blockchain Technology for improved Efficiency',
#  'EQUI disrupts the traditional venture investment market by empowering the crypto community to join the next generation of venture capital investors',
#  'The decentralized platform for gamers developers and investors',
#  'RoBET is going to be the first platform for crypto sports betting and cryptocurrency exchange',
#  'The first ever Blockchain based Real Estate Investment Trust REIT to ensure profitable returns for subscribers',
#  'The sports marketplace where you can invest in your worldwide idols by making use of the magic of blockchain technology to present a transparent process',
#  'The worlds most secure cash  crypto platform',
#  'The ALLSTOCKS Network is a distributed global stock exchange platform which aims to interface with all major stock exchanges and stock brokers around the world',
#  'RealCasino is a decentralized distributed casino gaming platform',
#  'Paygine is an open financial platform designed to operate within its own proprietary banking structure and designed to serve cryptobusiness needs',
#  'Teacher Coin TCH Crypto Currency for Educators provides a Universal platform for Teachers to purchase and sell resources and plan for Retirement',
#  'COTI Currency of the Internet spearheading the mass adoption of digital currencies',
#  'The New Global Currency for Travel and Tourism',
#  'Winstars is a decentralized gaming platform with a catalog of gambling resources the core is built on Blockchain and smart contracts',
#  'The worlds first settlement service using block chain technology that realizing low commission high security immediate settlement',
#  'Live Energy and Data Trading Protocol  Bringing efficiency and affordability to energy use through renewable energy systemswhich can be traded peertopeer',
#  'DataBroker DAO is the first marketplace to sell  buy sensor data through the use of Blockchain Technology',
#  'Essentia is the interoperations and data management framework forged by a whole new set of protocols',
#  'A revolutionary project using sentiment analysis for crypto trading through sophisticated algorithms',
#  'XSEARCH  Innovating Research System using the power of blockchain technology',
#  'Verasity is a nextgeneration video sharing platform designed to liberate creators and benefit viewers',
#  'Smart wallet  Currency for Delphi Intelligent carsThis is a token used in Delphi intelligent  driverless cars for use by car',
#  'A lifetime cloud mining service provider managed by a Danish company and a group of passionate professionals',
#  'A revolutionary digital asset exchange which is simple secure and sustainable',
#  'Worlds first decentralised open source and device independent computer based on Blockchain Technology',
#  'Fundraising platform linked to a humanitarian crypto emergency fund',
#  'The Worlds First 0 commission insurance on the Blockchain  making insurance more affordable',
#  'AbacasXchange is a universal exchange that allows you to trade exchange or transfer Any Asset Anywhere Anytime',
#  'BEAT is a SportAlliance project to help promote Sporting and Healthy activities',
#  'Artificial Intelligence AI and Robotics Ecosystem Powered by Blockchain Technology',
#  'Utilities Bill Payments Made Simple Pay telecom electricity gas and water bills with one click',
#  'FTEC is an ecosystem of intelligent services and neural networks for conducting effective trading activities on cryptocurrency markets',
#  'A new era in the crypto world through simple shopping and easy payment',
#  'Luckchemy is a scalable and provably fair online gambling platform driven by a unique combination of blockchain technology and offchain cryptography',
#  'The blockchain based AI platform providing personal assistance in cannabis industry',
#  'Decentralized marketplace with multilevel cashback',
#  'RecordsKeeper is an OpenSource Public Platform with an independant Mineable Blockchain for Record Keeping  Data Security',
#  'IP Protected contentcreation platform social media network and marketplace',
#  'Play review and Share to Earn on an open Gaming Platform which makes use of the Blockchain',
#  'Television Ecosystem on the Blockchain which enables directs connection between viewers advertisers and content creators',
#  'Connecting and rewarding participants in online referral programs power by Blockchain Technology',
#  'CriptoHub is a Brazilian cryptocurrency exchange bringing unique benefits Brazil',
#  'Valorem Foundation is building a niche ecommerce platform for 99 of the market',
#  'Coinet Financing Platform is a decentralized P2P platform that will directly connect investors and project owners We will follow the DAICO model',
#  'Expansion of sustainable freshwater aquaculture facility in Australia to grow premium quality fish',
#  'LendsBay is system for trusted financial transactions between people based on transparency and blockchain technology',
#  'The Blockchain Solution disrupting the global General Aviation Business',
#  'Tokenizing the world of fitness to create healthier lives for all around the globe using the power of blockchain technology',
#  'First blockchain community for safer driving and help drive down car insurance costs',
#  'AwardWinning German Company is changing Car Ownership forever by incorporating the magic of Blockchain Technology',
#  'Monitor Trade Invest Spend',
#  'A decentralized blockchain powered peertopeer platform for favors and minijobs around the world',
#  'Sports Token and Decentralized Ecosystem That Knows Your Favorite Team',
#  'PRnetwork is an incentivebased voting protocol designed to decentralized the reputation and value of everything',
#  'A solution for Bounty hunters For ICO For blockchain community For everyone']

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
import nltk
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
stemmer = SnowballStemmer("english")
np.random.seed(2018)
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\wsaadallah\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatize_stemming(text):
    lemmentized_text = WordNetLemmatizer().lemmatize(text, pos='v')
    return SnowballStemmer.stem(lemmentized_text)
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
doc_sample = documents[np.random.randint(0, len(documents))]
print('original document: {}'.format(doc_sample))
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample))
# Out:
# original document: Modular marketplace supernetwork initially powering the Cannabis industry
# ['Modular', 'marketplace', 'supernetwork', 'initially', 'powering', 'the', 'Cannabis', 'industry']
#
#
#  tokenized and lemmatized document:
# preprocessed text : ['modular', 'marketplace', 'supernetwork', 'initially', 'powering', 'the', 'cannabis', 'industry']
# modular
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-16f783099166> in <module>()
#       6 print(words)
#       7 print('\n\n tokenized and lemmatized document: ')
# ----> 8 print(preprocess(doc_sample))
#
# <ipython-input-47-8329b42da330> in preprocess(text)
#       8     for token in gensim.utils.simple_preprocess(text):
#       9         if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
# ---> 10             result.append(lemmatize_stemming(token))
#      11     return result
#
# <ipython-input-47-8329b42da330> in lemmatize_stemming(text)
#       2     lemmentized_text = WordNetLemmatizer().lemmatize(text, pos='v')
#       3     print(lemmentized_text)
# ----> 4     return SnowballStemmer.stem(lemmentized_text)
#       5 def preprocess(text):
#       6     result = []
#
# TypeError: stem() missing 1 required positional argument: 'token'

# %%
# Out:
# run

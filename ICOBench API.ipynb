# %%
import requests
import json
import hmac
import hashlib
import base64

# %%
class IcoBench:
    icoBenchApi = {
        "ICOBENCH_PRIVATE_KEY": "d4dbfe76-8cae-4e27-ad37-b29ef3eeb20b",
        "ICOBENCH_PUBLIC_KEY": "0361ce25-350d-4112-8b7e-82ef53b16806",
        "API_URL": "https://icobench.com/api/v1/"
    }

    sign=''

    @classmethod
    def sendIcoBenchRequest(cls, queryParams=(), pathParams={}, data=()):
        hash = hmac.new(cls.icoBenchApi["ICOBENCH_PRIVATE_KEY"].encode('utf-8'), ''.encode('utf-8'), hashlib.sha384)

        dataJSON = json.dumps(data)
        hash.update(dataJSON.encode('utf-8'))
        cls.sign = hash.digest()
        cls.sign = base64.b64encode(cls.sign)

        request_headers = {
            'Accept': 'application/json',
            'Content-Type': 'application/json',
            'X-ICObench-Key': cls.icoBenchApi["ICOBENCH_PUBLIC_KEY"],
            'X-ICObench-Sig': cls.sign
        }

        url = cls.icoBenchApi["API_URL"];
        for val in pathParams:
            url = url + val + "/"
        if all(queryParams) and url.endswith('/'):
            url = url[:-1]
        dataJSON = json.dumps(data)

        response = requests.post(url=url, params=queryParams, data=dataJSON, headers=request_headers)
        return response.json()

    @classmethod
    def getIcos(cls, queryParams=(), pathParams=["icos", "all"], data=()):
        return IcoBench.sendIcoBenchRequest(queryParams=queryParams, pathParams=pathParams, data=data)

    @classmethod
    def getIco(cls, queryParams=(), pathParams=["ico", "1"], data=()):
        return IcoBench.sendIcoBenchRequest(queryParams=queryParams, pathParams=pathParams, data=data)

    @classmethod
    def getOther(cls, queryParams=(), pathParams=["other", "stats"], data=()):
        return IcoBench.sendIcoBenchRequest(queryParams=queryParams, pathParams=pathParams, data=data)

    @classmethod
    def getPeople(cls, queryParams=(), pathParams=["people", "registered"], data=()):
        return IcoBench.sendIcoBenchRequest(queryParams=queryParams, pathParams=pathParams, data=data)

    @classmethod
    def getFilters(cls, queryParams=(), pathParams=["icos", "filters"], data=()):
        return IcoBench.sendIcoBenchRequest(queryParams=queryParams, pathParams=pathParams, data=data)

# %%
IcoBench.getIcos(data={'status' : 'ended'})
# Out:
# {'icos': 2190,
#  'pages': 183,
#  'currentPage': 0,
#  'results': [{'id': 3021,
#    'name': 'WisePass',
#    'url': 'https://icobench.com/ico/wisepass',
#    'logo': 'https://icobench.com/images/icos/icons/wisepass.jpg',
#    'desc': 'PASS tokens will change the way cryptocurrency holders utilize their assets.',
#    'rating': 3.3,
#    'premium': 0,
#    'raised': 0,
#    'dates': {'preIcoStart': '2018-05-10 09:00:00',
#     'preIcoEnd': '2018-06-10 08:59:59',
#     'icoStart': '2018-06-10 09:00:00',
#     'icoEnd': '2018-08-10 08:59:59'}},
#   {'id': 775,
#    'name': '4NEW',
#    'url': 'https://icobench.com/ico/4new',
#    'logo': 'https://icobench.com/images/icos/icons/4new.jpg',
#    'desc': '4NEW is the world’s first Waste to Energy power plant entirely integrated on the blockchain network pioneering Tokenized Electricity.',
#    'rating': 4.1,
#    'premium': 0,
#    'raised': 42100000,
#    'dates': {'preIcoStart': '2017-10-17 00:00:00',
#     'preIcoEnd': '2017-12-15 00:00:00',
#     'icoStart': '2018-06-01 00:00:00',
#     'icoEnd': '2018-08-10 00:00:00'}},
#   {'id': 2296,
#    'name': 'MIB',
#    'url': 'https://icobench.com/ico/mib',
#    'logo': 'https://icobench.com/images/icos/icons/mib.jpg',
#    'desc': 'MIB is a SmartX blockchain platform that allows anybody to participate in mining with smartphones and connect to more businesses anytime and anywhere.',
#    'rating': 2,
#    'premium': 0,
#    'raised': 0,
#    'dates': {'preIcoStart': '2018-03-19 00:00:00',
#     'preIcoEnd': '2018-03-25 00:00:00',
#     'icoStart': '2018-07-20 00:00:00',
#     'icoEnd': '2018-08-10 00:00:00'}},
#   {'id': 4193,
#    'name': 'MintFlint',
#    'url': 'https://icobench.com/ico/mintflint',
#    'logo': 'https://icobench.com/images/icos/icons/mintflint.jpg',
#    'desc': 'Token economies are used in a wide range of settings to encourage desirable behavior.',
#    'rating': 2,
#    'premium': 0,
#    'raised': 1208,
#    'dates': {'preIcoStart': '0000-00-00 00:00:00',
#     'preIcoEnd': '0000-00-00 00:00:00',
#     'icoStart': '2018-07-07 00:00:00',
#     'icoEnd': '2018-08-10 00:00:00'}},
#   {'id': 2624,
#    'name': 'Shopiblock',
#    'url': 'https://icobench.com/ico/shopiblock',
#    'logo': 'https://icobench.com/images/icos/icons/shopiblock.jpg',
#    'desc': 'Shopiblock is a decentralized White-label SaaS provider. The first decentralized shop software as a service on the market.',
#    'rating': 2.8,
#    'premium': 0,
#    'raised': -1,
#    'dates': {'preIcoStart': '2018-04-28 09:00:00',
#     'preIcoEnd': '2018-05-15 08:59:59',
#     'icoStart': '2018-06-01 09:00:00',
#     'icoEnd': '2018-08-09 08:59:59'}},
#   {'id': 3533,
#    'name': 'EventJoin',
#    'url': 'https://icobench.com/ico/eventjoin',
#    'logo': 'https://icobench.com/images/icos/icons/eventjoin.jpg',
#    'desc': 'EventJoin is an ecosystem for professionals to connect before, during, and after an event.',
#    'rating': 1.8,
#    'premium': 0,
#    'raised': -1,
#    'dates': {'preIcoStart': '0000-00-00 00:00:00',
#     'preIcoEnd': '0000-00-00 00:00:00',
#     'icoStart': '2018-05-11 00:00:00',
#     'icoEnd': '2018-08-09 00:00:00'}},
#   {'id': 1027,
#    'name': 'Zodiaq',
#    'url': 'https://icobench.com/ico/zodiaq',
#    'logo': 'https://icobench.com/images/icos/icons/zodiaq.jpg',
#    'desc': 'Zodiaq is a crypto-fiat platform, it contains a bank, an exchange, a hedge fund, and a PSD2 compliant payment operator.',
#    'rating': 3.8,
#    'premium': 0,
#    'raised': -1,
#    'dates': {'preIcoStart': '2018-05-21 00:00:00',
#     'preIcoEnd': '2018-06-23 00:00:00',
#     'icoStart': '2018-07-08 00:00:00',
#     'icoEnd': '2018-08-07 00:00:00'}},
#   {'id': 1831,
#    'name': 'Crypto Angel',
#    'url': 'https://icobench.com/ico/crypto-angel',
#    'logo': 'https://icobench.com/images/icos/icons/crypto-angel.jpg',
#    'desc': 'A blockchain based AI life assistant, designed to enhance human thinking, planning, and decision-making process.',
#    'rating': 3.9,
#    'premium': 0,
#    'raised': -1,
#    'dates': {'preIcoStart': '0000-00-00 00:00:00',
#     'preIcoEnd': '0000-00-00 00:00:00',
#     'icoStart': '2018-07-07 00:00:00',
#     'icoEnd': '2018-08-07 00:00:00'}},
#   {'id': 3852,
#    'name': 'Ledgit',
#    'url': 'https://icobench.com/ico/ledgit',
#    'logo': 'https://icobench.com/images/icos/icons/ledgit.jpg',
#    'desc': 'A Blockchain-as-a-service (BaaS) platform offering transparent provenance solutions for authentication and legacy heritage solutions.',
#    'rating': 2.3,
#    'premium': 0,
#    'raised': -1,
#    'dates': {'preIcoStart': '2018-03-01 00:00:00',
#     'preIcoEnd': '2018-07-06 00:00:00',
#     'icoStart': '2018-07-07 00:00:00',
#     'icoEnd': '2018-08-07 00:00:00'}},
#   {'id': 3535,
#    'name': 'Inmediate',
#    'url': 'https://icobench.com/ico/inmediate',
#    'logo': 'https://icobench.com/images/icos/icons/inmediate.jpg',
#    'desc': 'Making policies transparent and trustworthy, by powering Smart Contract Insurance.',
#    'rating': 3.4,
#    'premium': 0,
#    'raised': 5000000,
#    'dates': {'preIcoStart': '2018-07-06 09:00:00',
#     'preIcoEnd': '2018-07-13 09:00:00',
#     'icoStart': '2018-07-18 09:00:00',
#     'icoEnd': '2018-08-06 09:00:00'}},
#   {'id': 1535,
#    'name': 'Streamity',
#    'url': 'https://icobench.com/ico/streamity',
#    'logo': 'https://icobench.com/images/icos/icons/streamity.jpg',
#    'desc': 'We will develop fair and completely transparent StreamDesk service for the cryptocurrency-fiat money exchange without intermediaries.',
#    'rating': 4.2,
#    'premium': 0,
#    'raised': 4200000,
#    'dates': {'preIcoStart': '0000-00-00 00:00:00',
#     'preIcoEnd': '0000-00-00 00:00:00',
#     'icoStart': '2018-06-25 09:00:00',
#     'icoEnd': '2018-08-06 00:00:00'}},
#   {'id': 1578,
#    'name': 'BotGaming',
#    'url': 'https://icobench.com/ico/botgaming',
#    'logo': 'https://icobench.com/images/icos/icons/botgaming.jpg',
#    'desc': 'BOT is an utility token based on ERC20 standards. The key feature of the token is its’ use as ingame currency. It will be a purely utility token.',
#    'rating': 2.6,
#    'premium': 0,
#    'raised': -1,
#    'dates': {'preIcoStart': '2018-05-14 09:00:00',
#     'preIcoEnd': '2018-06-11 00:00:00',
#     'icoStart': '2018-07-09 00:00:00',
#     'icoEnd': '2018-08-06 00:00:00'}}]}
